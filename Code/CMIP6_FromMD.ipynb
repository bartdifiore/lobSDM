# %% [markdown]
# # Preliminaries
# To get to this point:
#
# 1. In the terminal from the project directory, run `pixi run jupyter-lab`
# 2. This should open up a web browser with Jupyter lab running. Copy the URL
# 3. Come back to programming IDE, and then find where you can select a kernel and select the existing Jupyter server option
# 4. You should be prompted to enter the web address, which is the address copied in step 2.
# 5. Next, it will ask for a password. This should be the token displayed in the terminal when you ran the `pixi run jupyter-lab` command, copy and paste that.
# 6. It will then ask about the Python environment to use, and there you should be able to select the pixi one created as part of this project.
# 7. All done, should be good to start running the .ipynb chunks.

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import gcsfs
from dask.diagnostics import ProgressBar
from numpy import unique
import cf_xarray
import operator
import os
import sys
sys.path.append('Code/')
import fcts
import glob

# %% [markdown]
# # Setting up model info

# %%
# models we care about
source_list = ['IPSL-CM6A-LR',
'CMCC-CM2-SR5',
'MIROC6',
'CanESM5',
'MRI-ESM2-0',
'HadGEM3-GC31-LL',
'GFDL-CM4',
'CESM2',
'CESM2-WACCM',
'CIESM',
'CNRM-CM6-1',
'CNRM-ESM2-1',
'CanESM5-CanOE',
'EC-Earth3',
'EC-Earth3-Veg',
'EC-Earth3-Veg-LR',
'FGOALS-g3',
'FGOALS-f3-L',
'FIO-ESM-2-0',
'GISS-E2-1-G',
'INM-CM4-8',
'INM-CM5-0',
'MIROC-ES2L',
'NESM3',
'NorESM2-LM',
'NorESM2-MM',
'UKESM1-0-LL']

# enter the var of interest {so, thetao, tos}
variable_id = 'thetao'
TOP = False # True for bottom salinty or temperature

# enter the table (based on the frequency of measurements)
table_id = 'Omon'

# Enter the experiments of interest {'historical', 'ssp585', 'ssp126'}
filter_list = ['historical']
experiment_run = 'historical'
grp1 = 'source_id' # used for grouping normally don't need to change
grp2 = 'member_id' # used for grouping normally don't need to change

# Output path
path = "/Users/aallyn/Library/CloudStorage/Box-Box/RES_Data/CMIP6/Historical/"

# data catalog is stored as a 30MB CSV file
AllModels = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')

# the columns correspond to the CMIP6 controlled vocab

# To run a suite of models
df_var = AllModels.query(f"variable_id == '{variable_id}' & table_id == '{table_id}' & experiment_id == @filter_list")
filteredModels = fcts.ExperimentFilter(df_var, grp1, grp2)
filteredModels_grid = filteredModels.query(f"source_id == @source_list").reset_index(drop=True)

print(filteredModels)
# Out:
#             source_id   member_id  Number_of_exp activity_id  \
# 0          ACCESS-CM2    r1i1p1f1              1        CMIP
# 1       ACCESS-ESM1-5   r11i1p1f1              1        CMIP
# 2       AWI-CM-1-1-MR    r1i1p1f1              1        CMIP
# 3      AWI-ESM-1-1-LR    r1i1p1f1              1        CMIP
# 4         BCC-CSM2-MR    r1i1p1f1              1        CMIP
# 5            BCC-ESM1    r1i1p1f1              1        CMIP
# 6         CAMS-CSM1-0    r1i1p1f1              1        CMIP
# 7          CAS-ESM2-0    r1i1p1f1              1        CMIP
# 8               CESM2   r10i1p1f1              1        CMIP
# 9           CESM2-FV2    r1i1p1f1              1        CMIP
# 10        CESM2-WACCM    r1i1p1f1              1        CMIP
# 11    CESM2-WACCM-FV2    r1i1p1f1              1        CMIP
# 12              CIESM    r1i1p1f1              1        CMIP
# 13       CMCC-CM2-HR4    r1i1p1f1              1        CMIP
# 14       CMCC-CM2-SR5    r1i1p1f1              1        CMIP
# 15          CMCC-ESM2    r1i1p1f1              1        CMIP
# 16         CNRM-CM6-1   r10i1p1f2              1        CMIP
# 17      CNRM-CM6-1-HR    r1i1p1f2              1        CMIP
# 18        CNRM-ESM2-1   r10i1p1f2              1        CMIP
# 19            CanESM5   r10i1p1f1              1        CMIP
# 20      CanESM5-CanOE    r1i1p2f1              1        CMIP
# 21           E3SM-1-0    r1i1p1f1              1        CMIP
# 22           E3SM-1-1    r1i1p1f1              1        CMIP
# 23       E3SM-1-1-ECA    r1i1p1f1              1        CMIP
# 24          EC-Earth3  r101i1p1f1              1        CMIP
# 25  EC-Earth3-AerChem    r1i1p1f1              1        CMIP
# 26       EC-Earth3-CC    r1i1p1f1              1        CMIP
# 27      EC-Earth3-Veg   r12i1p1f1              1        CMIP
# 28   EC-Earth3-Veg-LR    r1i1p1f1              1        CMIP
# 29        FGOALS-f3-L    r1i1p1f1              1        CMIP
# 30          FGOALS-g3    r1i1p1f1              1        CMIP
# 31        FIO-ESM-2-0    r1i1p1f1              1        CMIP
# 32           GFDL-CM4    r1i1p1f1              1        CMIP
# 33          GFDL-ESM4    r1i1p1f1              1        CMIP
# 34        GISS-E2-1-G  r101i1p1f1              1        CMIP
# 35     GISS-E2-1-G-CC    r1i1p1f1              1        CMIP
# 36        GISS-E2-1-H   r10i1p1f1              1        CMIP
# 37    HadGEM3-GC31-LL    r1i1p1f3              1        CMIP
# 38    HadGEM3-GC31-MM    r1i1p1f3              1        CMIP
# 39        ICON-ESM-LR    r1i1p1f1              1        CMIP
# 40          INM-CM4-8    r1i1p1f1              1        CMIP
# 41          INM-CM5-0   r10i1p1f1              1        CMIP
# 42    IPSL-CM5A2-INCA    r1i1p1f1              1        CMIP
# 43       IPSL-CM6A-LR   r10i1p1f1              1        CMIP
# 44  IPSL-CM6A-LR-INCA    r1i1p1f1              1        CMIP
# 45         MCM-UA-1-0    r1i1p1f1              1        CMIP
# 46         MIROC-ES2L   r10i1p1f2              1        CMIP
# 47             MIROC6   r10i1p1f1              1        CMIP
# 48    MPI-ESM-1-2-HAM    r1i1p1f1              1        CMIP
# 49      MPI-ESM1-2-HR   r10i1p1f1              1        CMIP
# 50      MPI-ESM1-2-LR   r10i1p1f1              1        CMIP
# 51         MRI-ESM2-0    r1i1p1f1              1        CMIP
# 52              NESM3    r1i1p1f1              1        CMIP
# 53            NorCPM1   r10i1p1f1              1        CMIP
# 54         NorESM2-LM    r1i1p1f1              1        CMIP
# 55         NorESM2-MM    r1i1p1f1              1        CMIP
# 56        SAM0-UNICON    r1i1p1f1              1        CMIP
# 57            TaiESM1    r1i1p1f1              1        CMIP
# 58        UKESM1-0-LL   r10i1p1f2              1        CMIP
#
#          institution_id experiment_id table_id variable_id grid_label  \
# 0          CSIRO-ARCCSS    historical     Omon      thetao         gn
# 1                 CSIRO    historical     Omon      thetao         gn
# 2                   AWI    historical     Omon      thetao         gn
# 3                   AWI    historical     Omon      thetao         gn
# 4                   BCC    historical     Omon      thetao         gn
# 5                   BCC    historical     Omon      thetao         gn
# 6                  CAMS    historical     Omon      thetao         gn
# 7                   CAS    historical     Omon      thetao         gn
# 8                  NCAR    historical     Omon      thetao         gr
# 9                  NCAR    historical     Omon      thetao         gr
# 10                 NCAR    historical     Omon      thetao         gr
# 11                 NCAR    historical     Omon      thetao         gn
# 12                  THU    historical     Omon      thetao         gn
# 13                 CMCC    historical     Omon      thetao         gn
# 14                 CMCC    historical     Omon      thetao         gn
# 15                 CMCC    historical     Omon      thetao         gn
# 16         CNRM-CERFACS    historical     Omon      thetao         gn
# 17         CNRM-CERFACS    historical     Omon      thetao         gn
# 18         CNRM-CERFACS    historical     Omon      thetao         gn
# 19                CCCma    historical     Omon      thetao         gn
# 20                CCCma    historical     Omon      thetao         gn
# 21         E3SM-Project    historical     Omon      thetao         gr
# 22         E3SM-Project    historical     Omon      thetao         gr
# 23         E3SM-Project    historical     Omon      thetao         gr
# 24  EC-Earth-Consortium    historical     Omon      thetao         gn
# 25  EC-Earth-Consortium    historical     Omon      thetao         gn
# 26  EC-Earth-Consortium    historical     Omon      thetao         gn
# 27  EC-Earth-Consortium    historical     Omon      thetao         gr
# 28  EC-Earth-Consortium    historical     Omon      thetao         gn
# 29                  CAS    historical     Omon      thetao         gn
# 30                  CAS    historical     Omon      thetao         gn
# 31             FIO-QLNM    historical     Omon      thetao         gn
# 32            NOAA-GFDL    historical     Omon      thetao         gr
# 33            NOAA-GFDL    historical     Omon      thetao         gn
# 34            NASA-GISS    historical     Omon      thetao         gn
# 35            NASA-GISS    historical     Omon      thetao         gn
# 36            NASA-GISS    historical     Omon      thetao         gr
# 37                 MOHC    historical     Omon      thetao         gn
# 38                 MOHC    historical     Omon      thetao         gn
# 39                MPI-M    historical     Omon      thetao         gn
# 40                  INM    historical     Omon      thetao        gr1
# 41                  INM    historical     Omon      thetao        gr1
# 42                 IPSL    historical     Omon      thetao         gn
# 43                 IPSL    historical     Omon      thetao         gn
# 44                 IPSL    historical     Omon      thetao         gn
# 45                   UA    historical     Omon      thetao         gn
# 46                MIROC    historical     Omon      thetao         gn
# 47                MIROC    historical     Omon      thetao         gn
# 48    HAMMOZ-Consortium    historical     Omon      thetao         gn
# 49                MPI-M    historical     Omon      thetao         gn
# 50                MPI-M    historical     Omon      thetao         gn
# 51                  MRI    historical     Omon      thetao         gr
# 52                NUIST    historical     Omon      thetao         gn
# 53                  NCC    historical     Omon      thetao         gn
# 54                  NCC    historical     Omon      thetao         gn
# 55                  NCC    historical     Omon      thetao         gr
# 56                  SNU    historical     Omon      thetao         gn
# 57              AS-RCEC    historical     Omon      thetao         gn
# 58                 MOHC    historical     Omon      thetao         gn
#
#                                                zstore  dcpp_init_year  \
# 0   gs://cmip6/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/...             NaN
# 1   gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...             NaN
# 2   gs://cmip6/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/histor...             NaN
# 3   gs://cmip6/CMIP6/CMIP/AWI/AWI-ESM-1-1-LR/histo...             NaN
# 4   gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...             NaN
# 5   gs://cmip6/CMIP6/CMIP/BCC/BCC-ESM1/historical/...             NaN
# 6   gs://cmip6/CMIP6/CMIP/CAMS/CAMS-CSM1-0/histori...             NaN
# 7   gs://cmip6/CMIP6/CMIP/CAS/CAS-ESM2-0/historica...             NaN
# 8   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 9   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 10  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 11  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 12  gs://cmip6/CMIP6/CMIP/THU/CIESM/historical/r1i...             NaN
# 13  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-HR4/histor...             NaN
# 14  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...             NaN
# 15  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 16  gs://cmip6/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/...             NaN
# 17  gs://cmip6/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1-...             NaN
# 18  gs://cmip6/CMIP6/CMIP/CNRM-CERFACS/CNRM-ESM2-1...             NaN
# 19  gs://cmip6/CMIP6/CMIP/CCCma/CanESM5/historical...             NaN
# 20  gs://cmip6/CMIP6/CMIP/CCCma/CanESM5-CanOE/hist...             NaN
# 21  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-0/hi...             NaN
# 22  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1/hi...             NaN
# 23  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1-EC...             NaN
# 24  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 25  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 26  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 27  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 28  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 29  gs://cmip6/CMIP6/CMIP/CAS/FGOALS-f3-L/historic...             NaN
# 30  gs://cmip6/CMIP6/CMIP/CAS/FGOALS-g3/historical...             NaN
# 31  gs://cmip6/CMIP6/CMIP/FIO-QLNM/FIO-ESM-2-0/his...             NaN
# 32  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 33  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 34  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/hi...             NaN
# 35  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G-CC...             NaN
# 36  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-H/hi...             NaN
# 37  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-LL/his...             NaN
# 38  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN
# 39  gs://cmip6/CMIP6/CMIP/MPI-M/ICON-ESM-LR/histor...             NaN
# 40  gs://cmip6/CMIP6/CMIP/INM/INM-CM4-8/historical...             NaN
# 41  gs://cmip6/CMIP6/CMIP/INM/INM-CM5-0/historical...             NaN
# 42  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM5A2-INCA/his...             NaN
# 43  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 44  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR-INCA/h...             NaN
# 45  gs://cmip6/CMIP6/CMIP/UA/MCM-UA-1-0/historical...             NaN
# 46  gs://cmip6/CMIP6/CMIP/MIROC/MIROC-ES2L/histori...             NaN
# 47  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...             NaN
# 48  gs://cmip6/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ES...             NaN
# 49  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/hist...             NaN
# 50  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/hist...             NaN
# 51  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 52  gs://cmip6/CMIP6/CMIP/NUIST/NESM3/historical/r...             NaN
# 53  gs://cmip6/CMIP6/CMIP/NCC/NorCPM1/historical/r...             NaN
# 54  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/historica...             NaN
# 55  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-MM/historica...             NaN
# 56  gs://cmip6/CMIP6/CMIP/SNU/SAM0-UNICON/historic...             NaN
# 57  gs://cmip6/CMIP6/CMIP/AS-RCEC/TaiESM1/historic...             NaN
# 58  gs://cmip6/CMIP6/CMIP/MOHC/UKESM1-0-LL/histori...             NaN
#
#      version
# 0   20191108
# 1   20200803
# 2   20181218
# 3   20200212
# 4   20181126
# 5   20181129
# 6   20190708
# 7   20200306
# 8   20190313
# 9   20191120
# 10  20190808
# 11  20191120
# 12  20200417
# 13  20200904
# 14  20200616
# 15  20210114
# 16  20190125
# 17  20191021
# 18  20200117
# 19  20190429
# 20  20190429
# 21  20190826
# 22  20191204
# 23  20200127
# 24  20200919
# 25  20200624
# 26  20210113
# 27  20200925
# 28  20200919
# 29  20191007
# 30  20191012
# 31  20191125
# 32  20180701
# 33  20190726
# 34  20190815
# 35  20190815
# 36  20190403
# 37  20190624
# 38  20191216
# 39  20210215
# 40  20190530
# 41  20190712
# 42  20200729
# 43  20180803
# 44  20210216
# 45  20190731
# 46  20200318
# 47  20190311
# 48  20190627
# 49  20190710
# 50  20190710
# 51  20191205
# 52  20190703
# 53  20190914
# 54  20190815
# 55  20191108
# 56  20190323
# 57  20200630
# 58  20191213

# %% [markdown]
# # Extracting info

# %%
if variable_id in ["so", "thetao"]:

    # Only has to be defined once
    gcs = gcsfs.GCSFileSystem(token='anon')

    for i in range(len(filteredModels_grid)):
        source_id = filteredModels_grid.source_id[i]
        member_id = filteredModels_grid.member_id[i]
        experiment_id = filteredModels_grid.experiment_id[i]
        variable_id = filteredModels_grid.variable_id[i]
        if TOP == True:
            savePath = f'{path}RawTmpFiles/Surface_{variable_id}_{source_id}_{member_id}_{experiment_id}.nc'
        else:
            savePath = f'{path}RawTmpFiles/{variable_id}_{source_id}_{member_id}_{experiment_id}.nc'
        
        if os.path.exists(savePath):
            print(f"Skipping {savePath} as it already exists.")
            continue
        
        else :

            # get the path to a specific zarr store 0 index is first on list
            zstore = filteredModels_grid.zstore.values[i]

            # create a mutable-mapping-styly interface to the store
            mapper = gcs.get_mapper(zstore)

            # open it using xarray and zarr
            ds = xr.open_zarr(mapper, consolidated=True)
            ds = ds.compute()

            lonNames = list(ds.cf[['longitude']].coords)
            latNames = list(ds.cf[['latitude']].coords)

            try:
                vertNames = list(ds.cf[['vertical']].coords)
            except KeyError:
                vertNames = list(ds.cf[['Z']].coords)

            lons = ['lon', 'longitude', 'nav_lon']
            lats = ['lat', 'latitude', 'nav_lat']
            verts = ['lev', 'olevel']

            x_coord = list(set(lonNames).intersection(lons))[0]
            y_coord = list(set(latNames).intersection(lats))[0]
            depth_coord = list(set(vertNames).intersection(verts))[0]

            if len(ds[variable_id][x_coord].dims) == 2:
                multiIndex = True
            else:
                multiIndex = False

            try:
                levUnits = ds[depth_coord].units
            except AttributeError:
                print('No depth units')
                print(ds[depth_coord])
                print('Enter units')
                levUnits = input()

            if levUnits in ['m', 'meters']:
                maxDepth = 400
            elif levUnits in ['cm', 'centimeters']:
                maxDepth = 400 * 100
            else:
                ds[depth_coord]
                print('Check attributes')

            # download atlantic data
            x_coordMin = ds[x_coord].values.min()
            x_coordMax = ds[x_coord].values.max()

            if x_coordMin < 0:
                xmin = -100
                xmax = -40
            else:
                xmin = 260
                xmax = 320

            kwlon = {x_coord: slice(xmin, xmax)}
            kwlat = {y_coord: slice(20, 70)}

            if multiIndex == True:
                # for multi index
                atlantic = ds.where((xmin < ds[x_coord]) & (ds[x_coord] < xmax)
                                    & (20 < ds[y_coord]) & (ds[y_coord] < 70),
                                    drop=True)
                if experiment_id == 'historical':
                    atlantic = atlantic.sel(time=slice('1950-01-01', None))
                elif experiment_id == experiment_run:   # Need to update this experiment ID for each run
                    atlantic = atlantic.isel(time=slice(None, 1032))
                else:
                    print("Need to enter date range")
            else:
                # single index
                if experiment_id == 'historical':
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice("1950-01-01", None))
                elif experiment_id == experiment_run: # Need to update this experiment ID for each run
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice(None, '2100-12-31'))
                else:
                    print("Need to enter date range")


            if TOP == True:
                kwargs = {depth_coord: 0}
                ds = atlantic.isel(**kwargs)
                ds = ds.rename({depth_coord: 'surface'})

            else:

                kwargs = {depth_coord: slice(0, maxDepth)}
                bottom_400 = atlantic.sel(**kwargs)
                temp_array = bottom_400[variable_id]

                if multiIndex == True:
                    dims0 = bottom_400[y_coord].dims[0]
                    dims1 = bottom_400[y_coord].dims[1]
                else:
                    dims0 = y_coord
                    dims1 = x_coord

                depth_indices = fcts.find_deepest_depth_indices_CMIP6(bottom_400, dims0, dims1, variable_id, y_coord, x_coord)
                ind = xr.DataArray(depth_indices, dims=[dims0, dims1])

                kwdepth = {depth_coord: ind}
                dsSel = temp_array.isel(**kwdepth)
                ds = dsSel.to_dataset()
                ds = ds.rename({depth_coord: 'bottom'})

            delayed_obj = ds.to_netcdf(savePath, compute=False)

            with ProgressBar():
                results = delayed_obj.compute()
            
            if variable_id == "so" and experiment_id not in "historical":
                folder = glob.glob(f'{path}SurSalinity/StGrid/*')
                for file in folder:
                    df = fcts.checkDates(file)
                    ncTimes = ncTimes.append(df, ignore_index=True)
            
            if variable_id == "thetao" and experiment_id not in "historical":
                folder = glob.glob(f'{path}BottomT/StGrid/*')
                minmax = {'name': [name], 'minVal': [minVal], 'maxVal': [maxVal]}
                minmaxdf = pd.DataFrame(data=minmax)
                for file in folder:
                    df = fcts.checkMinMax(file, variable_id)
                    minmaxdf = minmaxdf.append(df, ignore_index=True)

            print(f'Finished {variable_id}_{source_id}_{member_id}_{experiment_id}.nc')

# Sea Surface Temperature
if variable_id == 'tos':
    for i in range(len(filteredModels_grid)):
        source_id = filteredModels_grid.source_id[i]
        member_id = filteredModels_grid.member_id[i]
        experiment_id = filteredModels_grid.experiment_id[i]
        variable_id = filteredModels_grid.variable_id[i]
        savePath = f'{path}RawTmpFiles/{variable_id}_{source_id}_{member_id}_{experiment_id}.nc'
        
        if os.path.exists(savePath):
            print(f"Skipping {savePath} as it already exists.")
            continue
        
        else :

            # get the path to a specific zarr store 0 index is first on list
            zstore = filteredModels_grid.zstore.values[i]

            # create a mutable-mapping-styly interface to the store
            mapper = gcs.get_mapper(zstore)

            # open it using xarray and zarr
            ds = xr.open_zarr(mapper, consolidated=True)
            ds = ds.compute()

            lons = ['lon', 'longitude', 'nav_lon']
            lats = ['lat', 'latitude', 'nav_lat']

            lonNames = list(ds.cf[['longitude']].coords)
            latNames = list(ds.cf[['latitude']].coords)

            x_coord = list(set(lonNames).intersection(lons))[0]
            y_coord = list(set(latNames).intersection(lats))[0]

            x_coordMin = ds[x_coord].values.min()
            x_coordMax = ds[x_coord].values.max()


            if len(ds[variable_id][x_coord].dims) == 2:
                multiIndex = True
            else:
                multiIndex = False


            if x_coordMin < 0:
                xmin = -100
                xmax = -40
            else:
                xmin = 260
                xmax = 320

            kwlon = {x_coord: slice(xmin, xmax)}
            kwlat = {y_coord: slice(20, 70)}

            if multiIndex == True:
                # for multi index
                atlantic = ds.where((xmin < ds[x_coord]) & (ds[x_coord] < xmax)
                                    & (20 < ds[y_coord]) & (ds[y_coord] < 70),
                                    drop=True)
                if experiment_id == 'historical':
                    atlantic = atlantic.sel(time=slice('1950-01-01', None))
                elif experiment_id == experiment_run:  # Need to update this experiment ID for each run
                    atlantic = atlantic.isel(time=slice(None, 1032))
                else:
                    print("Need to enter date range")
            else:
                # single index
                if experiment_id == 'historical':
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice("1950-01-01", None))
                elif experiment_id == experiment_run:  # Need to update this experiment ID for each run
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice(None, '2100-12-31'))
                else:
                    print("Need to enter date range")

            delayed_obj = atlantic.to_netcdf(savePath, compute=False)

            with ProgressBar():
                results = delayed_obj.compute()

names = {'name': [], 'minDate': [], 'maxData': [], 'length': []}
ncTimes = pd.DataFrame(data=names)
# Out:
# [########################################] | 100% Completed | 117.62 ms
# Finished thetao_CESM2_r10i1p1f1_historical.nc
# [########################################] | 100% Completed | 114.07 ms
# Finished thetao_CESM2-WACCM_r1i1p1f1_historical.nc
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
