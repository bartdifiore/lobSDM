# %% [markdown]
# # Preliminaries
# To get to this point...

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import gcsfs
from dask.diagnostics import ProgressBar
from numpy import unique
import cf_xarray
import operator
import os
import sys
sys.path.append('Code/')
import fcts
import glob

# %% [markdown]
# # Setting up model info

# %%
# models we care about
source_list = [
# 'IPSL-CM6A-LR',
'CMCC-CM2-SR5',
# 'MIROC6',
'CanESM5',
'MRI-ESM2-0',
# 'HadGEM3-GC31-LL',
'GFDL-CM4',
'CESM2',
'CESM2-WACCM',
# 'CIESM',
# 'CNRM-CM6-1',
# 'CNRM-ESM2-1',
'CanESM5-CanOE',
'EC-Earth3',
# 'EC-Earth3-Veg',
# 'EC-Earth3-Veg-LR',
'FGOALS-g3',
'FGOALS-f3-L',
'FIO-ESM-2-0',
# 'GISS-E2-1-G',
'INM-CM4-8',
'INM-CM5-0'
]
# 'MIROC-ES2L',
# 'NESM3',
# 'NorESM2-LM',
# 'NorESM2-MM',
# 'UKESM1-0-LL']

# enter the var of interest {so, thetao, tos}
variable_id = 'thetao'
TOP = False # True for bottom salinty or temperature

# enter the table (based on the frequency of measurements)
table_id = 'Omon'

# Enter the experiments of interest {'historical', 'ssp585', 'ssp126'}
filter_list = ['ssp585']
experiment_run = 'ssp585'
grp1 = 'source_id' # used for grouping normally don't need to change
grp2 = 'member_id' # used for grouping normally don't need to change

# Output path
path = "/Users/aallyn/Library/CloudStorage/Box-Box/RES_Data/CMIP6/SSP585/"

# data catalog is stored as a 30MB CSV file
AllModels = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')

# the columns correspond to the CMIP6 controlled vocab

# To run a suite of models
df_var = AllModels.query(f"variable_id == '{variable_id}' & table_id == '{table_id}' & experiment_id == @filter_list")
filteredModels = fcts.ExperimentFilter(df_var, grp1, grp2)
filteredModels_grid = filteredModels.query(f"source_id == @source_list").reset_index(drop=True)

print(filteredModels)
# Out:
#            source_id   member_id  Number_of_exp  activity_id  \
# 0         ACCESS-CM2    r1i1p1f1              1  ScenarioMIP
# 1      ACCESS-ESM1-5   r10i1p1f1              1  ScenarioMIP
# 2      AWI-CM-1-1-MR    r1i1p1f1              1  ScenarioMIP
# 3        BCC-CSM2-MR    r1i1p1f1              1  ScenarioMIP
# 4        CAMS-CSM1-0    r1i1p1f1              1  ScenarioMIP
# 5         CAS-ESM2-0    r1i1p1f1              1  ScenarioMIP
# 6              CESM2   r10i1p1f1              1  ScenarioMIP
# 7        CESM2-WACCM    r1i1p1f1              1  ScenarioMIP
# 8              CIESM    r1i1p1f1              1  ScenarioMIP
# 9       CMCC-CM2-SR5    r1i1p1f1              1  ScenarioMIP
# 10         CMCC-ESM2    r1i1p1f1              1  ScenarioMIP
# 11        CNRM-CM6-1    r1i1p1f2              1  ScenarioMIP
# 12     CNRM-CM6-1-HR    r1i1p1f2              1  ScenarioMIP
# 13       CNRM-ESM2-1    r1i1p1f2              1  ScenarioMIP
# 14           CanESM5   r10i1p1f1              1  ScenarioMIP
# 15     CanESM5-CanOE    r1i1p2f1              1  ScenarioMIP
# 16          E3SM-1-1    r1i1p1f1              1  ScenarioMIP
# 17         EC-Earth3  r101i1p1f1              1  ScenarioMIP
# 18      EC-Earth3-CC    r1i1p1f1              1  ScenarioMIP
# 19     EC-Earth3-Veg    r1i1p1f1              1  ScenarioMIP
# 20  EC-Earth3-Veg-LR    r1i1p1f1              1  ScenarioMIP
# 21       FGOALS-f3-L    r1i1p1f1              1  ScenarioMIP
# 22         FGOALS-g3    r1i1p1f1              1  ScenarioMIP
# 23       FIO-ESM-2-0    r1i1p1f1              1  ScenarioMIP
# 24          GFDL-CM4    r1i1p1f1              1  ScenarioMIP
# 25         GFDL-ESM4    r1i1p1f1              1  ScenarioMIP
# 26       GISS-E2-1-G    r1i1p3f1              1  ScenarioMIP
# 27   HadGEM3-GC31-LL    r1i1p1f3              1  ScenarioMIP
# 28   HadGEM3-GC31-MM    r1i1p1f3              1  ScenarioMIP
# 29         INM-CM4-8    r1i1p1f1              1  ScenarioMIP
# 30         INM-CM5-0    r1i1p1f1              1  ScenarioMIP
# 31      IPSL-CM6A-LR   r14i1p1f1              1  ScenarioMIP
# 32        MCM-UA-1-0    r1i1p1f2              1  ScenarioMIP
# 33        MIROC-ES2L   r10i1p1f2              1  ScenarioMIP
# 34            MIROC6   r10i1p1f1              1  ScenarioMIP
# 35     MPI-ESM1-2-HR    r1i1p1f1              1  ScenarioMIP
# 36     MPI-ESM1-2-LR   r10i1p1f1              1  ScenarioMIP
# 37        MRI-ESM2-0    r1i1p1f1              1  ScenarioMIP
# 38             NESM3    r1i1p1f1              1  ScenarioMIP
# 39        NorESM2-LM    r1i1p1f1              1  ScenarioMIP
# 40        NorESM2-MM    r1i1p1f1              1  ScenarioMIP
# 41           TaiESM1    r1i1p1f1              1  ScenarioMIP
# 42       UKESM1-0-LL    r1i1p1f2              1  ScenarioMIP
#
#          institution_id experiment_id table_id variable_id grid_label  \
# 0          CSIRO-ARCCSS        ssp585     Omon      thetao         gn
# 1                 CSIRO        ssp585     Omon      thetao         gn
# 2                   AWI        ssp585     Omon      thetao         gn
# 3                   BCC        ssp585     Omon      thetao         gn
# 4                  CAMS        ssp585     Omon      thetao         gn
# 5                   CAS        ssp585     Omon      thetao         gn
# 6                  NCAR        ssp585     Omon      thetao         gn
# 7                  NCAR        ssp585     Omon      thetao         gr
# 8                   THU        ssp585     Omon      thetao         gn
# 9                  CMCC        ssp585     Omon      thetao         gn
# 10                 CMCC        ssp585     Omon      thetao         gn
# 11         CNRM-CERFACS        ssp585     Omon      thetao         gn
# 12         CNRM-CERFACS        ssp585     Omon      thetao         gn
# 13         CNRM-CERFACS        ssp585     Omon      thetao         gn
# 14                CCCma        ssp585     Omon      thetao         gn
# 15                CCCma        ssp585     Omon      thetao         gn
# 16         E3SM-Project        ssp585     Omon      thetao         gr
# 17  EC-Earth-Consortium        ssp585     Omon      thetao         gn
# 18  EC-Earth-Consortium        ssp585     Omon      thetao         gn
# 19  EC-Earth-Consortium        ssp585     Omon      thetao         gn
# 20  EC-Earth-Consortium        ssp585     Omon      thetao         gn
# 21                  CAS        ssp585     Omon      thetao         gn
# 22                  CAS        ssp585     Omon      thetao         gn
# 23             FIO-QLNM        ssp585     Omon      thetao         gn
# 24            NOAA-GFDL        ssp585     Omon      thetao         gn
# 25            NOAA-GFDL        ssp585     Omon      thetao         gn
# 26            NASA-GISS        ssp585     Omon      thetao         gn
# 27                 MOHC        ssp585     Omon      thetao         gn
# 28                 MOHC        ssp585     Omon      thetao         gn
# 29                  INM        ssp585     Omon      thetao        gr1
# 30                  INM        ssp585     Omon      thetao        gr1
# 31                 IPSL        ssp585     Omon      thetao         gn
# 32                   UA        ssp585     Omon      thetao         gn
# 33                MIROC        ssp585     Omon      thetao         gn
# 34                MIROC        ssp585     Omon      thetao         gn
# 35                 DKRZ        ssp585     Omon      thetao         gn
# 36                MPI-M        ssp585     Omon      thetao         gn
# 37                  MRI        ssp585     Omon      thetao         gr
# 38                NUIST        ssp585     Omon      thetao         gn
# 39                  NCC        ssp585     Omon      thetao         gn
# 40                  NCC        ssp585     Omon      thetao         gr
# 41              AS-RCEC        ssp585     Omon      thetao         gn
# 42                 MOHC        ssp585     Omon      thetao         gn
#
#                                                zstore  dcpp_init_year  \
# 0   gs://cmip6/CMIP6/ScenarioMIP/CSIRO-ARCCSS/ACCE...             NaN
# 1   gs://cmip6/CMIP6/ScenarioMIP/CSIRO/ACCESS-ESM1...             NaN
# 2   gs://cmip6/CMIP6/ScenarioMIP/AWI/AWI-CM-1-1-MR...             NaN
# 3   gs://cmip6/CMIP6/ScenarioMIP/BCC/BCC-CSM2-MR/s...             NaN
# 4   gs://cmip6/CMIP6/ScenarioMIP/CAMS/CAMS-CSM1-0/...             NaN
# 5   gs://cmip6/CMIP6/ScenarioMIP/CAS/CAS-ESM2-0/ss...             NaN
# 6   gs://cmip6/CMIP6/ScenarioMIP/NCAR/CESM2/ssp585...             NaN
# 7   gs://cmip6/CMIP6/ScenarioMIP/NCAR/CESM2-WACCM/...             NaN
# 8   gs://cmip6/CMIP6/ScenarioMIP/THU/CIESM/ssp585/...             NaN
# 9   gs://cmip6/CMIP6/ScenarioMIP/CMCC/CMCC-CM2-SR5...             NaN
# 10  gs://cmip6/CMIP6/ScenarioMIP/CMCC/CMCC-ESM2/ss...             NaN
# 11  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...             NaN
# 12  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...             NaN
# 13  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...             NaN
# 14  gs://cmip6/CMIP6/ScenarioMIP/CCCma/CanESM5/ssp...             NaN
# 15  gs://cmip6/CMIP6/ScenarioMIP/CCCma/CanESM5-Can...             NaN
# 16  gs://cmip6/CMIP6/ScenarioMIP/E3SM-Project/E3SM...             NaN
# 17  gs://cmip6/CMIP6/ScenarioMIP/EC-Earth-Consorti...             NaN
# 18  gs://cmip6/CMIP6/ScenarioMIP/EC-Earth-Consorti...             NaN
# 19  gs://cmip6/CMIP6/ScenarioMIP/EC-Earth-Consorti...             NaN
# 20  gs://cmip6/CMIP6/ScenarioMIP/EC-Earth-Consorti...             NaN
# 21  gs://cmip6/CMIP6/ScenarioMIP/CAS/FGOALS-f3-L/s...             NaN
# 22  gs://cmip6/CMIP6/ScenarioMIP/CAS/FGOALS-g3/ssp...             NaN
# 23  gs://cmip6/CMIP6/ScenarioMIP/FIO-QLNM/FIO-ESM-...             NaN
# 24  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-CM...             NaN
# 25  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
# 26  gs://cmip6/CMIP6/ScenarioMIP/NASA-GISS/GISS-E2...             NaN
# 27  gs://cmip6/CMIP6/ScenarioMIP/MOHC/HadGEM3-GC31...             NaN
# 28  gs://cmip6/CMIP6/ScenarioMIP/MOHC/HadGEM3-GC31...             NaN
# 29  gs://cmip6/CMIP6/ScenarioMIP/INM/INM-CM4-8/ssp...             NaN
# 30  gs://cmip6/CMIP6/ScenarioMIP/INM/INM-CM5-0/ssp...             NaN
# 31  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 32  gs://cmip6/CMIP6/ScenarioMIP/UA/MCM-UA-1-0/ssp...             NaN
# 33  gs://cmip6/CMIP6/ScenarioMIP/MIROC/MIROC-ES2L/...             NaN
# 34  gs://cmip6/CMIP6/ScenarioMIP/MIROC/MIROC6/ssp5...             NaN
# 35  gs://cmip6/CMIP6/ScenarioMIP/DKRZ/MPI-ESM1-2-H...             NaN
# 36  gs://cmip6/CMIP6/ScenarioMIP/MPI-M/MPI-ESM1-2-...             NaN
# 37  gs://cmip6/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ss...             NaN
# 38  gs://cmip6/CMIP6/ScenarioMIP/NUIST/NESM3/ssp58...             NaN
# 39  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 40  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-MM/ss...             NaN
# 41  gs://cmip6/CMIP6/ScenarioMIP/AS-RCEC/TaiESM1/s...             NaN
# 42  gs://cmip6/CMIP6/ScenarioMIP/MOHC/UKESM1-0-LL/...             NaN
#
#      version
# 0   20210317
# 1   20210318
# 2   20181218
# 3   20190319
# 4   20190708
# 5   20201230
# 6   20200528
# 7   20190815
# 8   20200417
# 9   20200622
# 10  20210126
# 11  20190219
# 12  20191202
# 13  20191021
# 14  20190429
# 15  20190429
# 16  20201201
# 17  20200918
# 18  20210113
# 19  20200919
# 20  20201201
# 21  20191012
# 22  20191230
# 23  20200114
# 24  20180701
# 25  20180701
# 26  20200115
# 27  20200114
# 28  20200515
# 29  20190603
# 30  20190724
# 31  20191121
# 32  20190731
# 33  20201222
# 34  20200623
# 35  20190710
# 36  20190710
# 37  20200120
# 38  20190731
# 39  20191108
# 40  20191108
# 41  20210416
# 42  20190726

# %% [markdown]
# # Extracting info

# %%
if variable_id in ["so", "thetao"]:

    # Only has to be defined once
    gcs = gcsfs.GCSFileSystem(token='anon')

    for i in range(len(filteredModels_grid)):
        source_id = filteredModels_grid.source_id[i]
        member_id = filteredModels_grid.member_id[i]
        experiment_id = filteredModels_grid.experiment_id[i]
        variable_id = filteredModels_grid.variable_id[i]
        if TOP == True:
            savePath = f'{path}RawTmpFiles/Surface_{variable_id}_{source_id}_{member_id}_{experiment_id}.nc'
        else:
            savePath = f'{path}RawTmpFiles/{variable_id}_{source_id}_{member_id}_{experiment_id}.nc'
        
        if os.path.exists(savePath):
            print(f"Skipping {savePath} as it already exists.")
            continue
        
        else :
            print(f"Working on {savePath}")
            # get the path to a specific zarr store 0 index is first on list
            zstore = filteredModels_grid.zstore.values[i]

            # create a mutable-mapping-styly interface to the store
            mapper = gcs.get_mapper(zstore)

            # open it using xarray and zarr
            ds = xr.open_zarr(mapper, consolidated=True)
            ds = ds.compute()

            lonNames = list(ds.cf[['longitude']].coords)
            latNames = list(ds.cf[['latitude']].coords)

            try:
                vertNames = list(ds.cf[['vertical']].coords)
            except KeyError:
                vertNames = list(ds.cf[['Z']].coords)

            lons = ['lon', 'longitude', 'nav_lon']
            lats = ['lat', 'latitude', 'nav_lat']
            verts = ['lev', 'olevel']

            x_coord = list(set(lonNames).intersection(lons))[0]
            y_coord = list(set(latNames).intersection(lats))[0]
            depth_coord = list(set(vertNames).intersection(verts))[0]

            if len(ds[variable_id][x_coord].dims) == 2:
                multiIndex = True
            else:
                multiIndex = False

            try:
                levUnits = ds[depth_coord].units
            except AttributeError:
                print('No depth units')
                print(ds[depth_coord])
                print('Enter units')
                levUnits = input()

            if levUnits in ['m', 'meters']:
                maxDepth = 400
            elif levUnits in ['cm', 'centimeters']:
                maxDepth = 400 * 100
            else:
                ds[depth_coord]
                print('Check attributes')

            # download atlantic data
            x_coordMin = ds[x_coord].values.min()
            x_coordMax = ds[x_coord].values.max()

            if x_coordMin < 0:
                xmin = -100
                xmax = -40
            else:
                xmin = 260
                xmax = 320

            kwlon = {x_coord: slice(xmin, xmax)}
            kwlat = {y_coord: slice(20, 70)}

            if multiIndex == True:
                # for multi index
                atlantic = ds.where((xmin < ds[x_coord]) & (ds[x_coord] < xmax)
                                    & (20 < ds[y_coord]) & (ds[y_coord] < 70),
                                    drop=True)
                if experiment_id == 'historical':
                    atlantic = atlantic.sel(time=slice('1950-01-01', None))
                elif experiment_id == experiment_run:   # Need to update this experiment ID for each run
                    atlantic = atlantic.isel(time=slice(None, 1032))
                else:
                    print("Need to enter date range")
            else:
                # single index
                if experiment_id == 'historical':
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice("1950-01-01", None))
                elif experiment_id == experiment_run: # Need to update this experiment ID for each run
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice(None, '2100-12-31'))
                else:
                    print("Need to enter date range")


            if TOP == True:
                kwargs = {depth_coord: 0}
                ds = atlantic.isel(**kwargs)
                ds = ds.rename({depth_coord: 'surface'})

            else:

                kwargs = {depth_coord: slice(0, maxDepth)}
                bottom_400 = atlantic.sel(**kwargs)
                temp_array = bottom_400[variable_id]

                if multiIndex == True:
                    dims0 = bottom_400[y_coord].dims[0]
                    dims1 = bottom_400[y_coord].dims[1]
                else:
                    dims0 = y_coord
                    dims1 = x_coord

                depth_indices = fcts.find_deepest_depth_indices_CMIP6(bottom_400, dims0, dims1, variable_id, y_coord, x_coord)
                ind = xr.DataArray(depth_indices, dims=[dims0, dims1])

                kwdepth = {depth_coord: ind}
                dsSel = temp_array.isel(**kwdepth)
                ds = dsSel.to_dataset()
                ds = ds.rename({depth_coord: 'bottom'})

            delayed_obj = ds.to_netcdf(savePath, compute=False)

            with ProgressBar():
                results = delayed_obj.compute()
            
            if variable_id == "so" and experiment_id not in "historical":
                folder = glob.glob(f'{path}SurSalinity/StGrid/*')
                for file in folder:
                    df = fcts.checkDates(file)
                    ncTimes = ncTimes.append(df, ignore_index=True)
            
            if variable_id == "thetao" and experiment_id not in "historical":
                folder = glob.glob(f'{path}BottomT/StGrid/*')
                minmax = {'name': [name], 'minVal': [minVal], 'maxVal': [maxVal]}
                minmaxdf = pd.DataFrame(data=minmax)
                for file in folder:
                    df = fcts.checkMinMax(file, variable_id)
                    minmaxdf = minmaxdf.append(df, ignore_index=True)

            print(f'Finished {variable_id}_{source_id}_{member_id}_{experiment_id}.nc')

# Sea Surface Temperature
if variable_id == 'tos':
    for i in range(len(filteredModels_grid)):
        source_id = filteredModels_grid.source_id[i]
        member_id = filteredModels_grid.member_id[i]
        experiment_id = filteredModels_grid.experiment_id[i]
        variable_id = filteredModels_grid.variable_id[i]
        savePath = f'{path}RawTmpFiles/{variable_id}_{source_id}_{member_id}_{experiment_id}.nc'
        
        if os.path.exists(savePath):
            print(f"Skipping {savePath} as it already exists.")
            continue
        
        else :

            # get the path to a specific zarr store 0 index is first on list
            zstore = filteredModels_grid.zstore.values[i]

            # create a mutable-mapping-styly interface to the store
            mapper = gcs.get_mapper(zstore)

            # open it using xarray and zarr
            ds = xr.open_zarr(mapper, consolidated=True)
            ds = ds.compute()

            lons = ['lon', 'longitude', 'nav_lon']
            lats = ['lat', 'latitude', 'nav_lat']

            lonNames = list(ds.cf[['longitude']].coords)
            latNames = list(ds.cf[['latitude']].coords)

            x_coord = list(set(lonNames).intersection(lons))[0]
            y_coord = list(set(latNames).intersection(lats))[0]

            x_coordMin = ds[x_coord].values.min()
            x_coordMax = ds[x_coord].values.max()


            if len(ds[variable_id][x_coord].dims) == 2:
                multiIndex = True
            else:
                multiIndex = False


            if x_coordMin < 0:
                xmin = -100
                xmax = -40
            else:
                xmin = 260
                xmax = 320

            kwlon = {x_coord: slice(xmin, xmax)}
            kwlat = {y_coord: slice(20, 70)}

            if multiIndex == True:
                # for multi index
                atlantic = ds.where((xmin < ds[x_coord]) & (ds[x_coord] < xmax)
                                    & (20 < ds[y_coord]) & (ds[y_coord] < 70),
                                    drop=True)
                if experiment_id == 'historical':
                    atlantic = atlantic.sel(time=slice('1950-01-01', None))
                elif experiment_id == experiment_run:  # Need to update this experiment ID for each run
                    atlantic = atlantic.isel(time=slice(None, 1032))
                else:
                    print("Need to enter date range")
            else:
                # single index
                if experiment_id == 'historical':
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice("1950-01-01", None))
                elif experiment_id == experiment_run:  # Need to update this experiment ID for each run
                    atlantic = ds.sel(**kwlon, **kwlat, time=slice(None, '2100-12-31'))
                else:
                    print("Need to enter date range")

            delayed_obj = atlantic.to_netcdf(savePath, compute=False)

            with ProgressBar():
                results = delayed_obj.compute()

names = {'name': [], 'minDate': [], 'maxData': [], 'length': []}
ncTimes = pd.DataFrame(data=names)
# Out:
# Working on /Users/aallyn/Library/CloudStorage/Box-Box/RES_Data/CMIP6/SSP585/RawTmpFiles/thetao_CESM2_r10i1p1f1_ssp585.nc
